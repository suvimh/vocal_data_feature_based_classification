# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Error (recording) condition KNN classifier
#
# Classification of the 7 different recording conditions including 1 correct singing condition and 6 conditions emulating common mistakes made by beginners.
#
# It would be interesing to provide these models (once they are generalised), once trained, the beginner data to see what errors it identifies for different beginners when they are starting their singing development and check whether the output corresponds to what a singing teacher would identify as the main things that beginner should focus on.

# %%
from scripts.knn_classifier import train_and_test_knn, evaluate_model
from scripts.utils import plot_confusion_matrix
DATA_FILE = 'data/voice_data_thesis_preprocessed.csv'

# %% [markdown]
# ## 1. Complete Data

# %%
# Train and test the model -- dont drop any columns all modalities
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording condition', audio_source='computer')
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

print("Accuracy: ", accuracy)  
print("Returned F1 score: ", f1)

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.9353233830845771
# Returned F1 score:  0.9353218054099204

# %% [markdown]
# #### Top 5 features only

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording condition', audio_source='computer', num_features=5)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

print("Accuracy: ", accuracy)  
print("Returned F1 score: ", f1)

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Selected features:  Index(['computer pose_landmark_24_y', 'computer pose_landmark_25_y',
#        'computer pose_landmark_28_y', 'computer pose_landmark_30_y',
#        'computer pose_landmark_32_y'],
#       dtype='object')
# Accuracy:  0.8725862214351969
# Returned F1 score:  0.872255415439113

# %% [markdown]
# ## 2. Audio Only

# %%
modalities = [
    "audio"
]

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording condition', audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

print("Accuracy: ", accuracy)  
print("Returned F1 score: ", f1)

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.25111729488152457
# Returned F1 score:  0.24684179666361644

# %% [markdown]
# ### Only top 5 audio features

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording condition', audio_source='computer',  num_features=5, modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

print("Accuracy: ", accuracy)  
print("Returned F1 score: ", f1)

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Selected features:  Index(['computer tristimulus3', 'computer mfcc fb40 1', 'computer mfcc fb40 3',
#        'computer mfcc fb40 5', 'computer mfcc fb40 10'],
#       dtype='object')
# Accuracy:  0.271270764819968
# Returned F1 score:  0.265136478493638

# %% [markdown]
# ## 3. Video Only

# %%
modalities = [
    "video"
]

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording condition', audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

print("Accuracy: ", accuracy)  
print("Returned F1 score: ", f1)

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.9992410827219833
# Returned F1 score:  0.9992411669731007

# %% [markdown]
# #### Only top 5 video features

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording condition', num_features=5, audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

print("Accuracy: ", accuracy)  
print("Returned F1 score: ", f1)

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Selected features:  Index(['computer pose_landmark_24_y', 'computer pose_landmark_25_y',
#        'computer pose_landmark_28_y', 'computer pose_landmark_30_y',
#        'computer pose_landmark_32_y'],
#       dtype='object')
# Accuracy:  0.8725862214351969
# Returned F1 score:  0.872255415439113

# %% [markdown]
# ## 4. Only Biosignal Data

# %%
modalities = [
    "biosignals"
]

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording condition', audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

print("Accuracy: ", accuracy)  
print("Returned F1 score: ", f1)

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.9955308204739016
# Returned F1 score:  0.9955304504314575
