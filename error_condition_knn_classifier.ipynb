# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Error (recording) condition KNN classifier
#
# Classification of the 7 different recording conditions including 1 correct singing condition and 6 conditions emulating common mistakes made by beginners.
#
# It would be interesing to provide these models (once they are generalised), once trained, the beginner data to see what errors it identifies for different beginners when they are starting their singing development and check whether the output corresponds to what a singing teacher would identify as the main things that beginner should focus on.
#
#
#
#
#
#
#
# ### Note on hunched back condition
# After further investigation, it seemed that for participant 14 (first participant for which an individual model is being developed), the hunched back case in the flow phonation recording session had limited ability to detect the face landmarks. After further analysis, it seemed this was because of the positioning of the participant in the recording condition in addition to the EEG sensor placement in the specific recording condition.

# %%
from scripts.knn_classifier import train_and_test_knn, evaluate_model
from scripts.utils import plot_confusion_matrix, calculate_metrics_multi_class
DATA_FILE = 'data/voice_data_thesis_preprocessed.csv'

# %% [markdown]
# ## 1. Complete Data

# %%
# Train and test the model -- dont drop any columns all modalities
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording_condition', audio_source='computer')
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

precision, recall= calculate_metrics_multi_class(y_test, y_pred)

print("Accuracy: ", round(accuracy, 4))
print("Returned F1 score: ", round(f1, 4))
print("Precision: ", round(precision, 4))
print("Recall: ", round(recall, 4))

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.9419
# Returned F1 score:  0.9419
# Precision:  0.9421
# Recall:  0.9419

# %% [markdown]
# #### Top 5 features only

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording_condition', audio_source='computer', num_features=5)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

precision, recall= calculate_metrics_multi_class(y_test, y_pred)

print("Accuracy: ", round(accuracy, 4))
print("Returned F1 score: ", round(f1, 4))
print("Precision: ", round(precision, 4))
print("Recall: ", round(recall, 4))



plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Selected features:  Index(['computer_pose_landmark_5_z', 'computer_pose_landmark_6_z',
#        'computer_pose_landmark_8_z', 'computer_pose_landmark_9_z',
#        'computer_pose_landmark_12_z'],
#       dtype='object')
# Accuracy:  0.8062
# Returned F1 score:  0.8069
# Precision:  0.8092
# Recall:  0.8062

# %% [markdown]
# ## 2. Audio Only

# %%
modalities = [
    "audio"
]

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording_condition', audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

precision, recall= calculate_metrics_multi_class(y_test, y_pred)

print("Accuracy: ", round(accuracy, 4))
print("Returned F1 score: ", round(f1, 4))
print("Precision: ", round(precision, 4))
print("Recall: ", round(recall, 4))



plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.2471
# Returned F1 score:  0.244
# Precision:  0.2491
# Recall:  0.2471

# %% [markdown]
# ### Only top 5 audio features

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording_condition', audio_source='computer',  num_features=5, modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

precision, recall= calculate_metrics_multi_class(y_test, y_pred)

print("Accuracy: ", round(accuracy, 4))
print("Returned F1 score: ", round(f1, 4))
print("Precision: ", round(precision, 4))
print("Recall: ", round(recall, 4))



plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Selected features:  Index(['computer_spec_cent', 'computer_mfcc_1', 'computer_mfcc_3',
#        'computer_mfcc_5', 'computer_mfcc_10'],
#       dtype='object')
# Accuracy:  0.2316
# Returned F1 score:  0.2269
# Precision:  0.2328
# Recall:  0.2316

# %% [markdown]
# ## 3. Video Only

# %%
modalities = [
    "video"
]

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording_condition', audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

precision, recall= calculate_metrics_multi_class(y_test, y_pred)

print("Accuracy: ", round(accuracy, 4))
print("Returned F1 score: ", round(f1, 4))
print("Precision: ", round(precision, 4))
print("Recall: ", round(recall, 4))



plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.999
# Returned F1 score:  0.999
# Precision:  0.999
# Recall:  0.999

# %% [markdown]
# #### Only top 5 video features

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording_condition', num_features=5, audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

precision, recall= calculate_metrics_multi_class(y_test, y_pred)

print("Accuracy: ", round(accuracy, 4))
print("Returned F1 score: ", round(f1, 4))
print("Precision: ", round(precision, 4))
print("Recall: ", round(recall, 4))



plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Selected features:  Index(['computer_pose_landmark_5_z', 'computer_pose_landmark_6_z',
#        'computer_pose_landmark_8_z', 'computer_pose_landmark_9_z',
#        'computer_pose_landmark_12_z'],
#       dtype='object')
# Accuracy:  0.8062
# Returned F1 score:  0.8069
# Precision:  0.8092
# Recall:  0.8062

# %% [markdown]
# ## 4. Only Biosignal Data

# %%
modalities = [
    "biosignals"
]

# %%
y_test, y_pred, class_names = train_and_test_knn(DATA_FILE, classify='recording_condition', audio_source='computer', modalities=modalities)
accuracy, f1, conf_matrix = evaluate_model(y_test, y_pred)

precision, recall= calculate_metrics_multi_class(y_test, y_pred)

print("Accuracy: ", round(accuracy, 4))
print("Returned F1 score: ", round(f1, 4))
print("Precision: ", round(precision, 4))
print("Recall: ", round(recall, 4))

plot_confusion_matrix(conf_matrix, class_names=class_names)
# Out:
# Accuracy:  0.9942
# Returned F1 score:  0.9942
# Precision:  0.9942
# Recall:  0.9942

# %% [markdown]
# # Separating classification of posture related flaws and other error conditions

# %% [markdown]
# ## 1. Posture only
